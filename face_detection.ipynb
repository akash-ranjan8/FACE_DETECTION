# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-ranjan8/FACE_DETECTION/blob/master/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y libsm6 libxext6
# !pip install -q -U opencv-python

# %% [markdown]
# #IMPORTING THE LIBRARIES

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #READING THE IMAGE

# %%
face_cascade = cv2.CascadeClassifier('face_detector.xml')
img = cv2.imread('a1.bmp')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[ 47  87 226 226]]

# %% [markdown]
# #DETECTING THE FACE BY MARKING THE RECTANGLE

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img)

# %% [markdown]
# #FOR TESTING 1

# %%
img1 = cv2.imread('a2.bmp')
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[356 130  52  52]
#  [229 135  51  51]
#  [160 138  52  52]
#  [301 139  54  54]
#  [247 226  60  60]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img1)

# %% [markdown]
# #FOR TESTING 2

# %%
img2 = cv2.imread('a4.bmp')
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[ 47 105 221 221]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img2)

# %% [markdown]
# #FOR TESTING 3

# %%
img3 = cv2.imread('a5.bmp')
gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[ 57 120 231 231]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img3,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img3)

# %% [markdown]
# #FOR TESTING 4

# %%
img4 = cv2.imread('a6.bmp')
gray = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[ 45 100 241 241]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img4,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img4)

# %% [markdown]
# #FOR TESTING 5

# %%
img5 = cv2.imread('a7.bmp')
gray = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[ 62  83 235 235]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img5,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img5)
